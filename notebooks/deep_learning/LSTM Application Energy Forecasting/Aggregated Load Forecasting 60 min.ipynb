# %% [markdown]
# # Aggregated Load using LSTM

# %% [markdown]
# ### Data Sources
# * Location: Austin, TX
# * Dates: 2016-01-01 to 2017-06-30
# * Weather: Weather Underground.
#  * Link: https://www.wunderground.com/
#  * Data resolution: ~ 1 hour
#  * Access: open
# * Energy: Pecan Street.
#  * Link: http://www.pecanstreet.org/
#  * Data resolution: 1 minute
#  * Access: universities

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt                        
# %matplotlib inline

def load_data(filename):
	data = pd.read_csv(filename, index_col="datetime")
	return data

# %% [markdown]
# ## Raw Data

# %% [markdown]
# ### Energy Data

# %%
## for a single house
resol = 1
households = [93, 114, 370, 545, 585, 661, 744, 1192, 1642,
				  1718, 1800, 1801, 2018, 2129, 2233, 2337, 2461,
				  2575, 2638, 2814, 2818]
# example: 2018, 2129, 2233, 2335, 2337, 2461, 2575, 2814
household = 93

raw_energy = load_data("preparedData/energy" + str(resol) + "_" + str(household) + ".csv")
raw_energy = raw_energy.loc['2015-12-24 00:00:00':'2017-06-30 23:59:00']

raw_energy.loc['2016-01-01 00:00:00':'2016-01-01 23:59:00']['use'].plot(style='r')
raw_energy.loc['2016-01-01 00:00:00':'2016-01-01 23:59:00']['gen'].plot(secondary_y=True, style='g')

# %%
raw_energy.loc['2016-08-01 00:00:00':'2016-08-01 23:59:00']['use'].plot(style='r')
raw_energy.loc['2016-08-01 00:00:00':'2016-08-01 23:59:00']['gen'].plot(secondary_y=True, style='g')

# %%
# for all the houses
resol = 1
# load households aggregated data
for i, household in enumerate(households):
    energy = load_data("preparedData/energy" + str(resol) + "_" + str(household) + ".csv")
    energy = energy.loc['2015-12-24 00:00:00':'2017-06-30 23:00:00']
    if i == 0:
        energyAgg = energy
    else:
        energyAgg += energy

# %%
energyAgg.loc['2016-01-02 00:00:00':'2016-01-02 23:59:00']['use'].plot(style='r')
energyAgg.loc['2016-01-02 00:00:00':'2016-01-02 23:59:00']['gen'].plot(secondary_y=True, style='g')

# %%
energyAgg.loc['2016-08-03 00:00:00':'2016-08-03 23:59:00']['use'].plot(style='r')
energyAgg.loc['2016-08-03 00:00:00':'2016-08-03 23:59:00']['gen'].plot(secondary_y=True, style='g')

# %% [markdown]
# ## Data interpolated adjusted to desired resolution

# %%
# forecast resolution
resol = 60

# load households aggregated data
for i, household in enumerate(households):
    energy = load_data("preparedData/energy" + str(resol) + "_" + str(household) + ".csv")
    energy = energy.loc['2015-12-24 00:00:00':'2017-06-30 23:00:00']
    if i == 0:
        energyAgg = energy
    else:
        energyAgg += energy

# %%
# load
energyAgg.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['use'].plot(style='r')
energyAgg.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['gen'].plot(secondary_y=True, style='g')

# %%
# load
energyAgg.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['use'].plot(style='r')
energyAgg.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['gen'].plot(secondary_y=True, style='g')

# %%
# load weather data
weather = load_data("preparedData/weather" + str(resol) + ".csv")
print(weather.head())

weather.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['tempC'].plot(style='r')
weather.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['hum'].plot(secondary_y=True, style='b')
# Out:
#                            hum     tempC
# datetime
# 2014-12-30 00:00:00  85.000000  6.700000
# 2014-12-30 01:00:00  85.040000  6.694000
# 2014-12-30 02:00:00  87.575315  6.312892
# 2014-12-30 03:00:00  92.543018  5.703941
# 2014-12-30 04:00:00  97.666667  6.058333

# %%
weather.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['tempC'].plot(style='r')
weather.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['hum'].plot(secondary_y=True, style='b')

# %% [markdown]
# # Power Demand Forecasting

# %% [markdown]
# ### Prepare Dataset to Feed LSTM

# %%
from datetime import date, datetime, timedelta
from sklearn.preprocessing import MinMaxScaler

days = [1, 2, 7]
def prepare_dataset_pv(weather, energy, resol, days):
	val_days = [1, 2, 3, 4, 5, 6, 7]
    
	# chunk data in days
	weather = weather.loc['2016-01-01':'2017-07-01']
	
	startDate = date(2016, 1, 1)
	endDate = date(2017, 6, 30)
	

	
	if resol == 60:
		minSt = '00'
	elif resol == 30:
		minSt = '30'
	elif resol == 15:
		minSt = '45'
		
	countTrain = 1
	countTest = 1
	countVal = 1
	
	while startDate <= endDate:
		startDateSt = startDate.strftime('%Y-%m-%d')
		startDatetimeSt = startDateSt + ' 00:00:00'
		endDatetimeSt = startDateSt +' 23:' + minSt + ':00'
		x = weather.loc[startDatetimeSt:endDatetimeSt]
		x = x.reset_index(drop=True)
		
		
        
		for day in days:
			# last week consumption
			date_past = startDate - timedelta(days=day)
			date_past = date_past.strftime('%Y-%m-%d')
			startDatetimeSt = date_past + ' 00:00:00'
			endDatetimeSt = date_past + ' 23:' + minSt + ':00'
			x_i = energy.loc[startDatetimeSt:endDatetimeSt]
			'''
			x_i = pd.DataFrame([x_i])
			'''
			x_i = x_i.reset_index(drop=True)
			column_name = 'day_' + str(day)
			x_i = pd.DataFrame(x_i['use'])
			x[column_name] = x_i
		
		x = x.as_matrix()
		#print(x.shape)
		x = x.reshape(1,x.shape[0], x.shape[1])
		#print(x.shape)
		
		
		
		# output on this day
		y = energy.loc[startDatetimeSt:endDatetimeSt]
		y = y.reset_index(drop=True)
		y = pd.DataFrame(y['use']).as_matrix()
		#print(y.shape)
		y = y.reshape(1, y.shape[0])
		#print(y.shape)
		
		if startDate < date(2017, 1, 1):
			day = startDate.day
			if int(day) in val_days:
				# validation set
				if countVal == 1:
					x_val = x
					y_val = y
					countVal += 1
				else:
					x_val = np.concatenate((x_val, x), axis=0)
					y_val = np.concatenate((y_val, y), axis=0)
			else:
				# training set
				if countTrain == 1:
					x_train = x
					y_train = y
					countTrain += 1
				else:
					x_train = np.concatenate((x_train, x), axis=0)
					y_train = np.concatenate((y_train, y), axis=0)
		elif startDate < date(2017, 7, 1):
			if countTest == 1:
				x_test = x
				y_test = y
				countTest += 1
			else:
				x_test = np.concatenate((x_test, x), axis=0)
				y_test = np.concatenate((y_test, y), axis=0)
		
		# update date
		startDate = startDate + timedelta(days=1)
		
	
	print(x_train.shape)
	print(y_train.shape)
	print(x_val.shape)
	print(y_val.shape)
	print(x_test.shape)
	print(y_test.shape)
	
	# ensure all data is float
	x_train = x_train.astype('float32')
	y_train = y_train.astype('float32')
	x_val = x_val.astype('float32')
	y_val = y_val.astype('float32')
	x_test = x_test.astype('float32')
	y_test = y_test.astype('float32')
    

    
	n_features = x_train.shape[2]
	x_train = x_train.reshape((-1, n_features))
	x_val = x_val.reshape((-1, n_features))
	x_test = x_test.reshape((-1, n_features))
	
	scalerFeatures = MinMaxScaler(feature_range=(0, 1))
	x_train = scalerFeatures.fit_transform(x_train)
	x_val = scalerFeatures.transform(x_val)
	x_test = scalerFeatures.transform(x_test)
	
	x_train = x_train.reshape((-1, 1440//resol, n_features))
	x_val = x_val.reshape((-1, 1440//resol, n_features))
	x_test = x_test.reshape((-1, 1440//resol, n_features))
	
	# Normalize y
	y_train = y_train.reshape((-1))
	y_val = y_val.reshape((-1))
	y_test = y_test.reshape((-1))
	
	scalerOutput = MinMaxScaler(feature_range=(0, 1))
	y_train = scalerOutput.fit_transform(y_train)
	y_val = scalerOutput.transform(y_val)
	y_test = scalerOutput.transform(y_test)
	
	y_train = y_train.reshape((-1, 1440//resol))
	y_val = y_val.reshape((-1, 1440//resol))
	y_test = y_test.reshape((-1, 1440//resol))
	
	print(x_train.shape)
	print(y_train.shape)
	print(x_val.shape)
	print(y_val.shape)
	print(x_test.shape)
	print(y_test.shape)
	
	return x_train, y_train, x_val, y_val, x_test, y_test, scalerFeatures, scalerOutput

# %%
x_train, y_train, x_val, y_val, x_test, y_test, scalerFeatures, scalerOutput\
		= prepare_dataset_pv(weather, energy, resol, days)
# Out:
# (282, 24, 5)
# (282, 24)
# (84, 24, 5)
# (84, 24)
# (181, 24, 5)
# (181, 24)
# (282, 24, 5)
# (282, 24)
# (84, 24, 5)
# (84, 24)
# (181, 24, 5)
# (181, 24)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %% [markdown]
# ### Define RNN Model

# %%
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import LSTM, Dense

timesteps = 1440//resol
input_shape = (x_train.shape[1], x_train.shape[2])

# design network
modelLoad = Sequential()
modelLoad.add(LSTM(timesteps, return_sequences=True, input_shape=input_shape))
modelLoad.add(LSTM(timesteps))
modelLoad.add(Dense(timesteps, activation='sigmoid'))
print(modelLoad.summary())

# compilation
# model.compile(loss='mae', optimizer='adam')
modelLoad.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 24, 24)            2880
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 24)                4704
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# =================================================================
# Total params: 8,184
# Trainable params: 8,184
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Training Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.aggre_load_'+str(resol)+'.hdf5',
								   verbose=1, save_best_only=True)
# fit network
history = modelLoad.fit(x_train, y_train, epochs=1000, batch_size=30,
						validation_data=(x_val, y_val), verbose=2,
						callbacks=[checkpointer], shuffle=False)

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
#
val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0026
# Epoch 518/1000
# Epoch 00517: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0026
# Epoch 519/1000
# Epoch 00518: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0026
# ...
# 0s - loss: 0.0011 - val_loss: 0.0028
# Epoch 830/1000
# Epoch 00829: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0028
# Epoch 831/1000
# Epoch 00830: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0027
# Epoch 832/1000
# Epoch 00831: val_loss did not improve
# 0s - loss: 9.7687e-04 - val_loss: 0.0028
# Epoch 833/1000
# Epoch 00832: val_loss did not improve
# 0s - loss: 9.6496e-04 - val_loss: 0.0028
# Epoch 834/1000
# Epoch 00833: val_loss did not improve
# 0s - loss: 9.4045e-04 - val_loss: 0.0028
# Epoch 835/1000
# Epoch 00834: val_loss did not improve
# 0s - loss: 9.3362e-04 - val_loss: 0.0028
# Epoch 836/1000
# Epoch 00835: val_loss did not improve
# 0s - loss: 9.1554e-04 - val_loss: 0.0028
# Epoch 837/1000
# Epoch 00836: val_loss did not improve
# 0s - loss: 9.1283e-04 - val_loss: 0.0028
# Epoch 838/1000
# Epoch 00837: val_loss did not improve
# 0s - loss: 8.9910e-04 - val_loss: 0.0028
# Epoch 839/1000
# Epoch 00838: val_loss did not improve
# 0s - loss: 8.9660e-04 - val_loss: 0.0028
# Epoch 840/1000
# Epoch 00839: val_loss did not improve
# 0s - loss: 8.8824e-04 - val_loss: 0.0028
# Epoch 841/1000
# Epoch 00840: val_loss did not improve
# 0s - loss: 8.8553e-04 - val_loss: 0.0028
# Epoch 842/1000
# Epoch 00841: val_loss did not improve
# 0s - loss: 8.8261e-04 - val_loss: 0.0028
# Epoch 843/1000
# Epoch 00842: val_loss did not improve
# 0s - loss: 8.7933e-04 - val_loss: 0.0028
# Epoch 844/1000
# Epoch 00843: val_loss did not improve
# 0s - loss: 8.8006e-04 - val_loss: 0.0028
# Epoch 845/1000
# Epoch 00844: val_loss did not improve
# 0s - loss: 8.7553e-04 - val_loss: 0.0028
# Epoch 846/1000
# Epoch 00845: val_loss did not improve
# 0s - loss: 8.7736e-04 - val_loss: 0.0028
# Epoch 847/1000
# Epoch 00846: val_loss did not improve
# 0s - loss: 8.7366e-04 - val_loss: 0.0028
# Epoch 848/1000
# Epoch 00847: val_loss did not improve
# 0s - loss: 8.7539e-04 - val_loss: 0.0028
# Epoch 849/1000
# Epoch 00848: val_loss did not improve
# 0s - loss: 8.7651e-04 - val_loss: 0.0028
# Epoch 850/1000
# Epoch 00849: val_loss did not improve
# 0s - loss: 8.7985e-04 - val_loss: 0.0028
# Epoch 851/1000
# Epoch 00850: val_loss did not improve
# 0s - loss: 8.8307e-04 - val_loss: 0.0028
# Epoch 852/1000
# Epoch 00851: val_loss did not improve
# 0s - loss: 8.9090e-04 - val_loss: 0.0028
# Epoch 853/1000
# Epoch 00852: val_loss did not improve
# 0s - loss: 8.8919e-04 - val_loss: 0.0029
# Epoch 854/1000
# Epoch 00853: val_loss did not improve
# 0s - loss: 9.0973e-04 - val_loss: 0.0028
# Epoch 855/1000
# Epoch 00854: val_loss did not improve
# 0s - loss: 9.1399e-04 - val_loss: 0.0029
# Epoch 856/1000
# Epoch 00855: val_loss did not improve
# 0s - loss: 9.4688e-04 - val_loss: 0.0028
# Epoch 857/1000
# Epoch 00856: val_loss did not improve
# 0s - loss: 9.4264e-04 - val_loss: 0.0029
# Epoch 858/1000
# Epoch 00857: val_loss did not improve
# 0s - loss: 9.5969e-04 - val_loss: 0.0028
# Epoch 859/1000
# Epoch 00858: val_loss did not improve
# 0s - loss: 9.1650e-04 - val_loss: 0.0028
# Epoch 860/1000
# Epoch 00859: val_loss did not improve
# 0s - loss: 9.0134e-04 - val_loss: 0.0028
# Epoch 861/1000
# Epoch 00860: val_loss did not improve
# 0s - loss: 9.0148e-04 - val_loss: 0.0028
# Epoch 862/1000
# Epoch 00861: val_loss did not improve
# 0s - loss: 9.1239e-04 - val_loss: 0.0028
# Epoch 863/1000
# Epoch 00862: val_loss did not improve
# 0s - loss: 9.0860e-04 - val_loss: 0.0029
# Epoch 864/1000
# Epoch 00863: val_loss did not improve
# 0s - loss: 9.1763e-04 - val_loss: 0.0028
# Epoch 865/1000
# Epoch 00864: val_loss did not improve
# 0s - loss: 9.1392e-04 - val_loss: 0.0029
# Epoch 866/1000
# Epoch 00865: val_loss did not improve
# 0s - loss: 9.2975e-04 - val_loss: 0.0028
# Epoch 867/1000
# Epoch 00866: val_loss did not improve
# 0s - loss: 9.4807e-04 - val_loss: 0.0029
# Epoch 868/1000
# Epoch 00867: val_loss did not improve
# 0s - loss: 9.7457e-04 - val_loss: 0.0028
# Epoch 869/1000
# Epoch 00868: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0029
# Epoch 870/1000
# Epoch 00869: val_loss did not improve
# 0s - loss: 9.9982e-04 - val_loss: 0.0029
# Epoch 871/1000
# Epoch 00870: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0029
# Epoch 872/1000
# Epoch 00871: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 873/1000
# Epoch 00872: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0029
# Epoch 874/1000
# Epoch 00873: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0028
# Epoch 875/1000
# Epoch 00874: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0028
# Epoch 876/1000
# Epoch 00875: val_loss did not improve
# 0s - loss: 9.4506e-04 - val_loss: 0.0028
# Epoch 877/1000
# Epoch 00876: val_loss did not improve
# 0s - loss: 9.2616e-04 - val_loss: 0.0028
# Epoch 878/1000
# Epoch 00877: val_loss did not improve
# 0s - loss: 9.1476e-04 - val_loss: 0.0028
# Epoch 879/1000
# Epoch 00878: val_loss did not improve
# 0s - loss: 9.4293e-04 - val_loss: 0.0028
# Epoch 880/1000
# Epoch 00879: val_loss did not improve
# 0s - loss: 9.3423e-04 - val_loss: 0.0029
# Epoch 881/1000
# Epoch 00880: val_loss did not improve
# 0s - loss: 9.2896e-04 - val_loss: 0.0028
# Epoch 882/1000
# Epoch 00881: val_loss did not improve
# 0s - loss: 9.3303e-04 - val_loss: 0.0028
# Epoch 883/1000
# Epoch 00882: val_loss did not improve
# 0s - loss: 9.1322e-04 - val_loss: 0.0028
# Epoch 884/1000
# Epoch 00883: val_loss did not improve
# 0s - loss: 9.1827e-04 - val_loss: 0.0028
# Epoch 885/1000
# Epoch 00884: val_loss did not improve
# 0s - loss: 8.8865e-04 - val_loss: 0.0028
# Epoch 886/1000
# Epoch 00885: val_loss did not improve
# 0s - loss: 8.8743e-04 - val_loss: 0.0028
# Epoch 887/1000
# Epoch 00886: val_loss did not improve
# 0s - loss: 8.7645e-04 - val_loss: 0.0028
# Epoch 888/1000
# Epoch 00887: val_loss did not improve
# 0s - loss: 8.8344e-04 - val_loss: 0.0028
# Epoch 889/1000
# Epoch 00888: val_loss did not improve
# 0s - loss: 8.8278e-04 - val_loss: 0.0029
# Epoch 890/1000
# Epoch 00889: val_loss did not improve
# 0s - loss: 8.9817e-04 - val_loss: 0.0028
# Epoch 891/1000
# Epoch 00890: val_loss did not improve
# 0s - loss: 8.9748e-04 - val_loss: 0.0029
# Epoch 892/1000
# Epoch 00891: val_loss did not improve
# 0s - loss: 9.1983e-04 - val_loss: 0.0028
# Epoch 893/1000
# Epoch 00892: val_loss did not improve
# 0s - loss: 9.0790e-04 - val_loss: 0.0029
# Epoch 894/1000
# Epoch 00893: val_loss did not improve
# 0s - loss: 9.1895e-04 - val_loss: 0.0028
# Epoch 895/1000
# Epoch 00894: val_loss did not improve
# 0s - loss: 8.9640e-04 - val_loss: 0.0028
# Epoch 896/1000
# Epoch 00895: val_loss did not improve
# 0s - loss: 8.8648e-04 - val_loss: 0.0028
# Epoch 897/1000
# Epoch 00896: val_loss did not improve
# 0s - loss: 8.8917e-04 - val_loss: 0.0028
# Epoch 898/1000
# Epoch 00897: val_loss did not improve
# 0s - loss: 8.8881e-04 - val_loss: 0.0029
# Epoch 899/1000
# Epoch 00898: val_loss did not improve
# 0s - loss: 9.1439e-04 - val_loss: 0.0028
# Epoch 900/1000
# Epoch 00899: val_loss did not improve
# 0s - loss: 9.2072e-04 - val_loss: 0.0029
# Epoch 901/1000
# Epoch 00900: val_loss did not improve
# 0s - loss: 9.2963e-04 - val_loss: 0.0028
# Epoch 902/1000
# Epoch 00901: val_loss did not improve
# 0s - loss: 8.9780e-04 - val_loss: 0.0028
# Epoch 903/1000
# Epoch 00902: val_loss did not improve
# 0s - loss: 8.8920e-04 - val_loss: 0.0028
# Epoch 904/1000
# Epoch 00903: val_loss did not improve
# 0s - loss: 8.8154e-04 - val_loss: 0.0029
# Epoch 905/1000
# Epoch 00904: val_loss did not improve
# 0s - loss: 8.8909e-04 - val_loss: 0.0028
# Epoch 906/1000
# Epoch 00905: val_loss did not improve
# 0s - loss: 8.9872e-04 - val_loss: 0.0029
# Epoch 907/1000
# Epoch 00906: val_loss did not improve
# 0s - loss: 9.2330e-04 - val_loss: 0.0028
# Epoch 908/1000
# Epoch 00907: val_loss did not improve
# 0s - loss: 9.2986e-04 - val_loss: 0.0030
# Epoch 909/1000
# Epoch 00908: val_loss did not improve
# 0s - loss: 9.7321e-04 - val_loss: 0.0028
# Epoch 910/1000
# Epoch 00909: val_loss did not improve
# 0s - loss: 9.9727e-04 - val_loss: 0.0029
# Epoch 911/1000
# Epoch 00910: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0029
# Epoch 912/1000
# Epoch 00911: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0029
# Epoch 913/1000
# Epoch 00912: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 914/1000
# Epoch 00913: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0030
# Epoch 915/1000
# Epoch 00914: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0029
# Epoch 916/1000
# Epoch 00915: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 917/1000
# Epoch 00916: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0028
# Epoch 918/1000
# Epoch 00917: val_loss did not improve
# 0s - loss: 9.9645e-04 - val_loss: 0.0029
# Epoch 919/1000
# Epoch 00918: val_loss did not improve
# 0s - loss: 9.5092e-04 - val_loss: 0.0029
# Epoch 920/1000
# Epoch 00919: val_loss did not improve
# 0s - loss: 9.9322e-04 - val_loss: 0.0028
# Epoch 921/1000
# Epoch 00920: val_loss did not improve
# 0s - loss: 9.5610e-04 - val_loss: 0.0029
# Epoch 922/1000
# Epoch 00921: val_loss did not improve
# 0s - loss: 9.8824e-04 - val_loss: 0.0028
# Epoch 923/1000
# Epoch 00922: val_loss did not improve
# 0s - loss: 9.7218e-04 - val_loss: 0.0030
# Epoch 924/1000
# Epoch 00923: val_loss did not improve
# 0s - loss: 9.8184e-04 - val_loss: 0.0029
# Epoch 925/1000
# Epoch 00924: val_loss did not improve
# 0s - loss: 9.8394e-04 - val_loss: 0.0029
# Epoch 926/1000
# Epoch 00925: val_loss did not improve
# 0s - loss: 9.7005e-04 - val_loss: 0.0029
# Epoch 927/1000
# Epoch 00926: val_loss did not improve
# 0s - loss: 9.9528e-04 - val_loss: 0.0029
# Epoch 928/1000
# Epoch 00927: val_loss did not improve
# 0s - loss: 9.5371e-04 - val_loss: 0.0028
# Epoch 929/1000
# Epoch 00928: val_loss did not improve
# 0s - loss: 9.5119e-04 - val_loss: 0.0029
# Epoch 930/1000
# Epoch 00929: val_loss did not improve
# 0s - loss: 9.0928e-04 - val_loss: 0.0028
# Epoch 931/1000
# Epoch 00930: val_loss did not improve
# 0s - loss: 8.9657e-04 - val_loss: 0.0028
# Epoch 932/1000
# Epoch 00931: val_loss did not improve
# 0s - loss: 8.7725e-04 - val_loss: 0.0028
# Epoch 933/1000
# Epoch 00932: val_loss did not improve
# 0s - loss: 8.7947e-04 - val_loss: 0.0029
# Epoch 934/1000
# Epoch 00933: val_loss did not improve
# 0s - loss: 8.8999e-04 - val_loss: 0.0029
# Epoch 935/1000
# Epoch 00934: val_loss did not improve
# 0s - loss: 9.0983e-04 - val_loss: 0.0029
# Epoch 936/1000
# Epoch 00935: val_loss did not improve
# 0s - loss: 9.2706e-04 - val_loss: 0.0029
# Epoch 937/1000
# Epoch 00936: val_loss did not improve
# 0s - loss: 9.3483e-04 - val_loss: 0.0029
# Epoch 938/1000
# Epoch 00937: val_loss did not improve
# 0s - loss: 9.3652e-04 - val_loss: 0.0029
# Epoch 939/1000
# Epoch 00938: val_loss did not improve
# 0s - loss: 9.2599e-04 - val_loss: 0.0028
# Epoch 940/1000
# Epoch 00939: val_loss did not improve
# 0s - loss: 9.1348e-04 - val_loss: 0.0029
# Epoch 941/1000
# Epoch 00940: val_loss did not improve
# 0s - loss: 9.1924e-04 - val_loss: 0.0028
# Epoch 942/1000
# Epoch 00941: val_loss did not improve
# 0s - loss: 9.2097e-04 - val_loss: 0.0028
# Epoch 943/1000
# Epoch 00942: val_loss did not improve
# 0s - loss: 8.9725e-04 - val_loss: 0.0029
# Epoch 944/1000
# Epoch 00943: val_loss did not improve
# 0s - loss: 9.0146e-04 - val_loss: 0.0028
# Epoch 945/1000
# Epoch 00944: val_loss did not improve
# 0s - loss: 8.9036e-04 - val_loss: 0.0029
# Epoch 946/1000
# Epoch 00945: val_loss did not improve
# 0s - loss: 9.0007e-04 - val_loss: 0.0028
# Epoch 947/1000
# Epoch 00946: val_loss did not improve
# 0s - loss: 8.9369e-04 - val_loss: 0.0029
# Epoch 948/1000
# Epoch 00947: val_loss did not improve
# 0s - loss: 9.0628e-04 - val_loss: 0.0028
# Epoch 949/1000
# Epoch 00948: val_loss did not improve
# 0s - loss: 8.9589e-04 - val_loss: 0.0029
# Epoch 950/1000
# Epoch 00949: val_loss did not improve
# 0s - loss: 8.9707e-04 - val_loss: 0.0029
# Epoch 951/1000
# Epoch 00950: val_loss did not improve
# 0s - loss: 8.9655e-04 - val_loss: 0.0029
# Epoch 952/1000
# Epoch 00951: val_loss did not improve
# 0s - loss: 9.1684e-04 - val_loss: 0.0030
# Epoch 953/1000
# Epoch 00952: val_loss did not improve
# 0s - loss: 9.8764e-04 - val_loss: 0.0030
# Epoch 954/1000
# Epoch 00953: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 955/1000
# Epoch 00954: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0031
# Epoch 956/1000
# Epoch 00955: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0029
# Epoch 957/1000
# Epoch 00956: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0029
# Epoch 958/1000
# Epoch 00957: val_loss did not improve
# 0s - loss: 9.4037e-04 - val_loss: 0.0029
# Epoch 959/1000
# Epoch 00958: val_loss did not improve
# 0s - loss: 9.5085e-04 - val_loss: 0.0028
# Epoch 960/1000
# Epoch 00959: val_loss did not improve
# 0s - loss: 9.3106e-04 - val_loss: 0.0029
# Epoch 961/1000
# Epoch 00960: val_loss did not improve
# 0s - loss: 9.6197e-04 - val_loss: 0.0029
# Epoch 962/1000
# Epoch 00961: val_loss did not improve
# 0s - loss: 9.3788e-04 - val_loss: 0.0030
# Epoch 963/1000
# Epoch 00962: val_loss did not improve
# 0s - loss: 9.6072e-04 - val_loss: 0.0029
# Epoch 964/1000
# Epoch 00963: val_loss did not improve
# 0s - loss: 9.6819e-04 - val_loss: 0.0030
# Epoch 965/1000
# Epoch 00964: val_loss did not improve
# 0s - loss: 9.7242e-04 - val_loss: 0.0029
# Epoch 966/1000
# Epoch 00965: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0030
# Epoch 967/1000
# Epoch 00966: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0030
# Epoch 968/1000
# Epoch 00967: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0030
# Epoch 969/1000
# Epoch 00968: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0030
# Epoch 970/1000
# Epoch 00969: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 971/1000
# Epoch 00970: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 972/1000
# Epoch 00971: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 973/1000
# Epoch 00972: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 974/1000
# Epoch 00973: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 975/1000
# Epoch 00974: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0029
# Epoch 976/1000
# Epoch 00975: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0030
# Epoch 977/1000
# Epoch 00976: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0029
# Epoch 978/1000
# Epoch 00977: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0029
# Epoch 979/1000
# Epoch 00978: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0029
# Epoch 980/1000
# Epoch 00979: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0029
# Epoch 981/1000
# Epoch 00980: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0029
# Epoch 982/1000
# Epoch 00981: val_loss did not improve
# 0s - loss: 9.9093e-04 - val_loss: 0.0029
# Epoch 983/1000
# Epoch 00982: val_loss did not improve
# 0s - loss: 9.5304e-04 - val_loss: 0.0028
# Epoch 984/1000
# Epoch 00983: val_loss did not improve
# 0s - loss: 9.1914e-04 - val_loss: 0.0029
# Epoch 985/1000
# Epoch 00984: val_loss did not improve
# 0s - loss: 8.9002e-04 - val_loss: 0.0028
# Epoch 986/1000
# Epoch 00985: val_loss did not improve
# 0s - loss: 8.9242e-04 - val_loss: 0.0029
# Epoch 987/1000
# Epoch 00986: val_loss did not improve
# 0s - loss: 8.7631e-04 - val_loss: 0.0028
# Epoch 988/1000
# Epoch 00987: val_loss did not improve
# 0s - loss: 8.7291e-04 - val_loss: 0.0029
# Epoch 989/1000
# Epoch 00988: val_loss did not improve
# 0s - loss: 8.5380e-04 - val_loss: 0.0028
# Epoch 990/1000
# Epoch 00989: val_loss did not improve
# 0s - loss: 8.4469e-04 - val_loss: 0.0029
# Epoch 991/1000
# Epoch 00990: val_loss did not improve
# 0s - loss: 8.3350e-04 - val_loss: 0.0028
# Epoch 992/1000
# Epoch 00991: val_loss did not improve
# 0s - loss: 8.2970e-04 - val_loss: 0.0029
# Epoch 993/1000
# Epoch 00992: val_loss did not improve
# 0s - loss: 8.2913e-04 - val_loss: 0.0029
# Epoch 994/1000
# Epoch 00993: val_loss did not improve
# 0s - loss: 8.2823e-04 - val_loss: 0.0029
# Epoch 995/1000
# Epoch 00994: val_loss did not improve
# 0s - loss: 8.3229e-04 - val_loss: 0.0029
# Epoch 996/1000
# Epoch 00995: val_loss did not improve
# 0s - loss: 8.3273e-04 - val_loss: 0.0029
# Epoch 997/1000
# Epoch 00996: val_loss did not improve
# 0s - loss: 8.3742e-04 - val_loss: 0.0029
# Epoch 998/1000
# Epoch 00997: val_loss did not improve
# 0s - loss: 8.4231e-04 - val_loss: 0.0029
# Epoch 999/1000
# Epoch 00998: val_loss did not improve
# 0s - loss: 8.4742e-04 - val_loss: 0.0029
# Epoch 1000/1000
# Epoch 00999: val_loss did not improve
# 0s - loss: 8.6506e-04 - val_loss: 0.0029

# %% [markdown]
# ### Testing Model

# %%
# reload parameters
modelLoad.load_weights('saved_models/weights.best.aggre_load_'+str(resol)+'.hdf5')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_pred = modelLoad.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Mean Square Error: %f" % mse)
print("Mean Absolute Error: %f" % mae)
# Out:
# Mean Square Error: 0.004621
# Mean Absolute Error: 0.043567

# %%
day = 179
plt.plot(y_pred[day,:], label='Predicted')
plt.plot(y_test[day,:], label='Real')
plt.plot(x_test[day,:,1], label='Temperature')
plt.legend()
plt.show()
