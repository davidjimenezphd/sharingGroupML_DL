# %% [markdown]
# # Household Load using LSTM

# %% [markdown]
# ### Data Sources
# * Location: Austin, TX
# * Dates: 2016-01-01 to 2017-06-30
# * Weather: Weather Underground.
#  * Link: https://www.wunderground.com/
#  * Data resolution: ~ 1 hour
#  * Access: open
# * Energy: Pecan Street.
#  * Link: http://www.pecanstreet.org/
#  * Data resolution: 1 minute
#  * Access: universities

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt                        
# %matplotlib inline

def load_data(filename):
	data = pd.read_csv(filename, index_col="datetime")
	return data

# forecast resolution
resol = 60
# household id selected
household = 93

# %%
# load weather data
weather = load_data("preparedData/weather" + str(resol) + ".csv")
print(weather.head())

weather.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['tempC'].plot(style='r')
weather.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['hum'].plot(secondary_y=True, style='b')
# Out:
#                            hum     tempC
# datetime
# 2014-12-30 00:00:00  85.000000  6.700000
# 2014-12-30 01:00:00  85.040000  6.694000
# 2014-12-30 02:00:00  87.575315  6.312892
# 2014-12-30 03:00:00  92.543018  5.703941
# 2014-12-30 04:00:00  97.666667  6.058333

# %%
weather.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['tempC'].plot(style='r')
weather.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['hum'].plot(secondary_y=True, style='b')

# %%
# load energy data
energy = load_data("preparedData/energy" + str(resol) + "_" + str(household) +".csv")
print(energy.head())

energy.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['use'].plot(style='r')
energy.loc['2016-01-01 00:00:00':'2016-01-01 23:00:00']['gen'].plot(secondary_y=True, style='g')
# Out:
#                           use  gen
# datetime
# 2015-12-23 00:00:00  1.174933  0.0
# 2015-12-23 01:00:00  0.899850  0.0
# 2015-12-23 02:00:00  0.432117  0.0
# 2015-12-23 03:00:00  0.402633  0.0
# 2015-12-23 04:00:00  0.573333  0.0

# %%
energy.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['use'].plot(style='r')
energy.loc['2016-08-01 00:00:00':'2016-08-01 23:00:00']['gen'].plot(secondary_y=True, style='g')

# %% [markdown]
# # Power Demand Forecasting

# %% [markdown]
# ### Prepare Dataset to Feed LSTM

# %%
from datetime import date, datetime, timedelta
from sklearn.preprocessing import MinMaxScaler

days = [1, 2, 7]
def prepare_dataset_pv(weather, energy, resol, days):
	val_days = [1, 2, 3, 4, 5, 6, 7]
    
	# chunk data in days
	weather = weather.loc['2016-01-01':'2017-07-01']
	
	startDate = date(2016, 1, 1)
	endDate = date(2017, 6, 30)
	
	n_features = 5

	x_train = np.empty((1, 1440//resol, n_features))
	y_train = np.empty((1, 1440//resol))
	
	x_val = np.empty((1, 1440//resol, n_features))
	y_val = np.empty((1, 1440//resol))
	
	if resol == 60:
		minSt = '00'
	elif resol == 30:
		minSt = '30'
	elif resol == 15:
		minSt = '45'
		
	countTrain = 1
	countTest = 1
	countVal = 1
	
	while startDate <= endDate:
		weekday = startDate.weekday()
		
		startDateSt = startDate.strftime('%Y-%m-%d')
		startDatetimeSt = startDateSt + ' 00:00:00'
		endDatetimeSt = startDateSt + ' 23:' + minSt + ':00'
		x = weather.loc[startDatetimeSt:endDatetimeSt]
		x = x.reset_index(drop=True)
		
		if weekday < 5:
			x['weekday'] = pd.DataFrame(data=np.zeros((1440//resol, 1)))
		else:
			x['weekday'] = pd.DataFrame(np.ones((1440 // resol, 1)))
		
		
		days = [1, 2, 7]
		
		for day in days:
			# last week consumption
			date_past = startDate - timedelta(days=day)
			date_past = date_past.strftime('%Y-%m-%d')
			startDatetimeSt = date_past + ' 00:00:00'
			endDatetimeSt = date_past + ' 23:' + minSt + ':00'
			x_i = energy.loc[startDatetimeSt:endDatetimeSt]
			'''
			x_i = pd.DataFrame([x_i])
			'''
			x_i = x_i.reset_index(drop=True)
			column_name = 'day_' + str(day)
			x_i = pd.DataFrame(x_i['gen'])
			x[column_name] = x_i
		
		x = x.as_matrix()
		# print(x.shape)
		x = x.reshape(1, x.shape[0], x.shape[1])
		# print(x.shape)
		
		
		
		# output on this day
		y = energy.loc[startDatetimeSt:endDatetimeSt]
		y = y.reset_index(drop=True)
		y = pd.DataFrame(y['gen']).as_matrix()
		# print(y.shape)
		y = y.reshape(1, y.shape[0])
		# print(y.shape)
		
		if startDate < date(2017, 1, 1):
			day = startDate.day
			if int(day) in val_days:
				# validation set
				if countVal == 1:
					x_val = x
					y_val = y
					countVal += 1
				else:
					x_val = np.concatenate((x_val, x), axis=0)
					y_val = np.concatenate((y_val, y), axis=0)
			else:
				# training set
				if countTrain == 1:
					x_train = x
					y_train = y
					countTrain += 1
				else:
					x_train = np.concatenate((x_train, x), axis=0)
					y_train = np.concatenate((y_train, y), axis=0)
		elif startDate < date(2017, 7, 1):
			if countTest == 1:
				x_test = x
				y_test = y
				countTest += 1
			else:
				x_test = np.concatenate((x_test, x), axis=0)
				y_test = np.concatenate((y_test, y), axis=0)
		
		# update date
		startDate = startDate + timedelta(days=1)
	
	print(x_train.shape)
	print(y_train.shape)
	print(x_val.shape)
	print(y_val.shape)
	print(x_test.shape)
	print(y_test.shape)
	
	# ensure all data is float
	x_train = x_train.astype('float32')
	y_train = y_train.astype('float32')
	x_val = x_val.astype('float32')
	y_val = y_val.astype('float32')
	x_test = x_test.astype('float32')
	y_test = y_test.astype('float32')
	
	n_features = x_train.shape[2]
	
	# Normalize X
	x_train = x_train.reshape((-1, n_features))
	x_val = x_val.reshape((-1, n_features))
	x_test = x_test.reshape((-1, n_features))
	
	scalerFeatures = MinMaxScaler(feature_range=(0, 1))
	x_train = scalerFeatures.fit_transform(x_train)
	x_val = scalerFeatures.transform(x_val)
	x_test = scalerFeatures.transform(x_test)
	
	x_train = x_train.reshape((-1, 1440 // resol, n_features))
	x_val = x_val.reshape((-1, 1440 // resol, n_features))
	x_test = x_test.reshape((-1, 1440 // resol, n_features))
	
	# Normalize y
	y_train = y_train.reshape((-1))
	y_val = y_val.reshape((-1))
	y_test = y_test.reshape((-1))
	
	scalerOutput = MinMaxScaler(feature_range=(0, 1))
	y_train = scalerOutput.fit_transform(y_train)
	y_val = scalerOutput.transform(y_val)
	y_test = scalerOutput.transform(y_test)
	
	y_train = y_train.reshape((-1, 1440 // resol))
	y_val = y_val.reshape((-1, 1440 // resol))
	y_test = y_test.reshape((-1, 1440 // resol))
	
	print(x_train.shape)
	print(y_train.shape)
	print(x_val.shape)
	print(y_val.shape)
	print(x_test.shape)
	print(y_test.shape)
	
	return x_train, y_train, x_val, y_val, x_test, y_test, scalerFeatures, scalerOutput

# %%
x_train, y_train, x_val, y_val, x_test, y_test, scalerFeatures, scalerOutput\
		= prepare_dataset_pv(weather, energy, resol, days)
# Out:
# (282, 24, 6)
# (282, 24)
# (84, 24, 6)
# (84, 24)
# (181, 24, 6)
# (181, 24)
# (282, 24, 6)
# (282, 24)
# (84, 24, 6)
# (84, 24)
# (181, 24, 6)
# (181, 24)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:321: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/alberto/.local/lib/python3.5/site-packages/sklearn/preprocessing/data.py:356: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %% [markdown]
# ### Define RNN Model

# %%
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import LSTM, Dense

timesteps = 1440//resol
input_shape = (x_train.shape[1], x_train.shape[2])

# design network
modelLoad = Sequential()
modelLoad.add(LSTM(timesteps, return_sequences=True, input_shape=input_shape))
modelLoad.add(LSTM(timesteps))
modelLoad.add(Dense(timesteps, activation='sigmoid'))
print(modelLoad.summary())

# compilation
# model.compile(loss='mae', optimizer='adam')
modelLoad.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 24, 24)            2976
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 24)                4704
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                600
# =================================================================
# Total params: 8,280
# Trainable params: 8,280
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Training Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.load_'+str(resol)+'.hdf5',
								   verbose=1, save_best_only=True)
# fit network
history = modelLoad.fit(x_train, y_train, epochs=1000, batch_size=30,
						validation_data=(x_val, y_val), verbose=2,
						callbacks=[checkpointer], shuffle=False)

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Train on 282 samples, validate on 84 samples
# Epoch 1/1000
# Epoch 00000: val_loss improved from inf to 0.16313, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.1721 - val_loss: 0.1631
# Epoch 2/1000
# Epoch 00001: val_loss improved from 0.16313 to 0.13714, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.1525 - val_loss: 0.1371
# Epoch 3/1000
# Epoch 00002: val_loss improved from 0.13714 to 0.09999, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.1210 - val_loss: 0.1000
# Epoch 4/1000
# Epoch 00003: val_loss improved from 0.09999 to 0.06725, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0848 - val_loss: 0.0672
# Epoch 5/1000
# Epoch 00004: val_loss improved from 0.06725 to 0.04530, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0568 - val_loss: 0.0453
# Epoch 6/1000
# Epoch 00005: val_loss improved from 0.04530 to 0.03243, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0387 - val_loss: 0.0324
# Epoch 7/1000
# Epoch 00006: val_loss improved from 0.03243 to 0.02628, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0294 - val_loss: 0.0263
# Epoch 8/1000
# Epoch 00007: val_loss improved from 0.02628 to 0.02341, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0250 - val_loss: 0.0234
# Epoch 9/1000
# Epoch 00008: val_loss improved from 0.02341 to 0.02187, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0230 - val_loss: 0.0219
# Epoch 10/1000
# Epoch 00009: val_loss improved from 0.02187 to 0.02101, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0218 - val_loss: 0.0210
# Epoch 11/1000
# Epoch 00010: val_loss improved from 0.02101 to 0.02047, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0212 - val_loss: 0.0205
# Epoch 12/1000
# Epoch 00011: val_loss improved from 0.02047 to 0.02008, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0207 - val_loss: 0.0201
# Epoch 13/1000
# Epoch 00012: val_loss improved from 0.02008 to 0.01978, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0203 - val_loss: 0.0198
# Epoch 14/1000
# Epoch 00013: val_loss improved from 0.01978 to 0.01953, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0201 - val_loss: 0.0195
# Epoch 15/1000
# Epoch 00014: val_loss improved from 0.01953 to 0.01933, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0198 - val_loss: 0.0193
# Epoch 16/1000
# Epoch 00015: val_loss improved from 0.01933 to 0.01916, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0196 - val_loss: 0.0192
# Epoch 17/1000
# Epoch 00016: val_loss improved from 0.01916 to 0.01901, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0195 - val_loss: 0.0190
# Epoch 18/1000
# Epoch 00017: val_loss improved from 0.01901 to 0.01889, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0193 - val_loss: 0.0189
# Epoch 19/1000
# Epoch 00018: val_loss improved from 0.01889 to 0.01878, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0192 - val_loss: 0.0188
# Epoch 20/1000
# Epoch 00019: val_loss improved from 0.01878 to 0.01868, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0191 - val_loss: 0.0187
# Epoch 21/1000
# Epoch 00020: val_loss improved from 0.01868 to 0.01860, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0190 - val_loss: 0.0186
# Epoch 22/1000
# Epoch 00021: val_loss improved from 0.01860 to 0.01852, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0189 - val_loss: 0.0185
# Epoch 23/1000
# Epoch 00022: val_loss improved from 0.01852 to 0.01846, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0189 - val_loss: 0.0185
# Epoch 24/1000
# Epoch 00023: val_loss improved from 0.01846 to 0.01840, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0188 - val_loss: 0.0184
# Epoch 25/1000
# Epoch 00024: val_loss improved from 0.01840 to 0.01835, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0188 - val_loss: 0.0184
# Epoch 26/1000
# Epoch 00025: val_loss improved from 0.01835 to 0.01831, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0187 - val_loss: 0.0183
# Epoch 27/1000
# Epoch 00026: val_loss improved from 0.01831 to 0.01827, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0187 - val_loss: 0.0183
# Epoch 28/1000
# Epoch 00027: val_loss improved from 0.01827 to 0.01823, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0186 - val_loss: 0.0182
# Epoch 29/1000
# Epoch 00028: val_loss improved from 0.01823 to 0.01819, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0186 - val_loss: 0.0182
# Epoch 30/1000
# Epoch 00029: val_loss improved from 0.01819 to 0.01816, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0186 - val_loss: 0.0182
# Epoch 31/1000
# Epoch 00030: val_loss improved from 0.01816 to 0.01813, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0185 - val_loss: 0.0181
# Epoch 32/1000
# Epoch 00031: val_loss improved from 0.01813 to 0.01811, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0185 - val_loss: 0.0181
# Epoch 33/1000
# Epoch 00032: val_loss improved from 0.01811 to 0.01808, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0185 - val_loss: 0.0181
# Epoch 34/1000
# Epoch 00033: val_loss improved from 0.01808 to 0.01806, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0185 - val_loss: 0.0181
# Epoch 35/1000
# Epoch 00034: val_loss improved from 0.01806 to 0.01804, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0184 - val_loss: 0.0180
# Epoch 36/1000
# Epoch 00035: val_loss improved from 0.01804 to 0.01802, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0184 - val_loss: 0.0180
# Epoch 37/1000
# Epoch 00036: val_loss improved from 0.01802 to 0.01800, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0184 - val_loss: 0.0180
# Epoch 38/1000
# Epoch 00037: val_loss improved from 0.01800 to 0.01798, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0184 - val_loss: 0.0180
# Epoch 39/1000
# Epoch 00038: val_loss improved from 0.01798 to 0.01796, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0184 - val_loss: 0.0180
# Epoch 40/1000
# Epoch 00039: val_loss improved from 0.01796 to 0.01795, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0184 - val_loss: 0.0179
# Epoch 41/1000
# Epoch 00040: val_loss improved from 0.01795 to 0.01793, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 42/1000
# Epoch 00041: val_loss improved from 0.01793 to 0.01792, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 43/1000
# Epoch 00042: val_loss improved from 0.01792 to 0.01791, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 44/1000
# Epoch 00043: val_loss improved from 0.01791 to 0.01789, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 45/1000
# Epoch 00044: val_loss improved from 0.01789 to 0.01788, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 46/1000
# Epoch 00045: val_loss improved from 0.01788 to 0.01787, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 47/1000
# Epoch 00046: val_loss improved from 0.01787 to 0.01786, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 48/1000
# Epoch 00047: val_loss improved from 0.01786 to 0.01785, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0183 - val_loss: 0.0179
# Epoch 49/1000
# Epoch 00048: val_loss improved from 0.01785 to 0.01784, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 50/1000
# Epoch 00049: val_loss improved from 0.01784 to 0.01783, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 51/1000
# Epoch 00050: val_loss improved from 0.01783 to 0.01782, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 52/1000
# Epoch 00051: val_loss improved from 0.01782 to 0.01782, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 53/1000
# Epoch 00052: val_loss improved from 0.01782 to 0.01781, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 54/1000
# Epoch 00053: val_loss improved from 0.01781 to 0.01780, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 55/1000
# Epoch 00054: val_loss improved from 0.01780 to 0.01780, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 56/1000
# Epoch 00055: val_loss improved from 0.01780 to 0.01779, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 57/1000
# Epoch 00056: val_loss improved from 0.01779 to 0.01778, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 58/1000
# Epoch 00057: val_loss improved from 0.01778 to 0.01778, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 59/1000
# Epoch 00058: val_loss improved from 0.01778 to 0.01777, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 60/1000
# Epoch 00059: val_loss improved from 0.01777 to 0.01776, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 61/1000
# Epoch 00060: val_loss improved from 0.01776 to 0.01776, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 62/1000
# Epoch 00061: val_loss improved from 0.01776 to 0.01775, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0182 - val_loss: 0.0178
# Epoch 63/1000
# Epoch 00062: val_loss improved from 0.01775 to 0.01775, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 64/1000
# Epoch 00063: val_loss improved from 0.01775 to 0.01774, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 65/1000
# Epoch 00064: val_loss improved from 0.01774 to 0.01774, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 66/1000
# Epoch 00065: val_loss improved from 0.01774 to 0.01774, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 67/1000
# Epoch 00066: val_loss improved from 0.01774 to 0.01773, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 68/1000
# Epoch 00067: val_loss improved from 0.01773 to 0.01773, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 69/1000
# Epoch 00068: val_loss improved from 0.01773 to 0.01772, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 70/1000
# Epoch 00069: val_loss improved from 0.01772 to 0.01772, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 71/1000
# Epoch 00070: val_loss improved from 0.01772 to 0.01772, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 72/1000
# Epoch 00071: val_loss improved from 0.01772 to 0.01771, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 73/1000
# Epoch 00072: val_loss improved from 0.01771 to 0.01771, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 74/1000
# Epoch 00073: val_loss improved from 0.01771 to 0.01771, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 75/1000
# Epoch 00074: val_loss improved from 0.01771 to 0.01770, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 76/1000
# Epoch 00075: val_loss improved from 0.01770 to 0.01770, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 77/1000
# Epoch 00076: val_loss improved from 0.01770 to 0.01770, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 78/1000
# Epoch 00077: val_loss improved from 0.01770 to 0.01769, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 79/1000
# Epoch 00078: val_loss improved from 0.01769 to 0.01769, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 80/1000
# Epoch 00079: val_loss improved from 0.01769 to 0.01769, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 81/1000
# Epoch 00080: val_loss improved from 0.01769 to 0.01769, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 82/1000
# Epoch 00081: val_loss improved from 0.01769 to 0.01768, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 83/1000
# Epoch 00082: val_loss improved from 0.01768 to 0.01768, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 84/1000
# Epoch 00083: val_loss improved from 0.01768 to 0.01768, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 85/1000
# Epoch 00084: val_loss improved from 0.01768 to 0.01768, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 86/1000
# Epoch 00085: val_loss improved from 0.01768 to 0.01767, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 87/1000
# Epoch 00086: val_loss improved from 0.01767 to 0.01767, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 88/1000
# Epoch 00087: val_loss improved from 0.01767 to 0.01767, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 89/1000
# Epoch 00088: val_loss improved from 0.01767 to 0.01767, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 90/1000
# Epoch 00089: val_loss improved from 0.01767 to 0.01767, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 91/1000
# Epoch 00090: val_loss improved from 0.01767 to 0.01766, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 92/1000
# Epoch 00091: val_loss improved from 0.01766 to 0.01766, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 93/1000
# Epoch 00092: val_loss improved from 0.01766 to 0.01766, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 94/1000
# Epoch 00093: val_loss improved from 0.01766 to 0.01766, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 95/1000
# Epoch 00094: val_loss improved from 0.01766 to 0.01766, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 96/1000
# Epoch 00095: val_loss improved from 0.01766 to 0.01765, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 97/1000
# Epoch 00096: val_loss improved from 0.01765 to 0.01765, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0181 - val_loss: 0.0177
# Epoch 98/1000
# Epoch 00097: val_loss improved from 0.01765 to 0.01765, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0177
# Epoch 99/1000
# Epoch 00098: val_loss improved from 0.01765 to 0.01765, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 100/1000
# Epoch 00099: val_loss improved from 0.01765 to 0.01765, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 101/1000
# Epoch 00100: val_loss improved from 0.01765 to 0.01765, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 102/1000
# Epoch 00101: val_loss improved from 0.01765 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 103/1000
# Epoch 00102: val_loss improved from 0.01764 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 104/1000
# Epoch 00103: val_loss improved from 0.01764 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 105/1000
# Epoch 00104: val_loss improved from 0.01764 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 106/1000
# Epoch 00105: val_loss improved from 0.01764 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 107/1000
# Epoch 00106: val_loss improved from 0.01764 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 108/1000
# Epoch 00107: val_loss improved from 0.01764 to 0.01764, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 109/1000
# Epoch 00108: val_loss improved from 0.01764 to 0.01763, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 110/1000
# Epoch 00109: val_loss improved from 0.01763 to 0.01763, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 111/1000
# Epoch 00110: val_loss improved from 0.01763 to 0.01763, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 112/1000
# Epoch 00111: val_loss improved from 0.01763 to 0.01763, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 113/1000
# Epoch 00112: val_loss improved from 0.01763 to 0.01763, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 114/1000
# Epoch 00113: val_loss improved from 0.01763 to 0.01763, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 115/1000
# Epoch 00114: val_loss improved from 0.01763 to 0.01762, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 116/1000
# Epoch 00115: val_loss improved from 0.01762 to 0.01762, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 117/1000
# Epoch 00116: val_loss improved from 0.01762 to 0.01762, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 118/1000
# Epoch 00117: val_loss improved from 0.01762 to 0.01762, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 119/1000
# Epoch 00118: val_loss improved from 0.01762 to 0.01761, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 120/1000
# Epoch 00119: val_loss improved from 0.01761 to 0.01761, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 121/1000
# Epoch 00120: val_loss improved from 0.01761 to 0.01761, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 122/1000
# Epoch 00121: val_loss improved from 0.01761 to 0.01760, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 123/1000
# Epoch 00122: val_loss improved from 0.01760 to 0.01760, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 124/1000
# Epoch 00123: val_loss improved from 0.01760 to 0.01759, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0180 - val_loss: 0.0176
# Epoch 125/1000
# Epoch 00124: val_loss improved from 0.01759 to 0.01758, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0179 - val_loss: 0.0176
# Epoch 126/1000
# Epoch 00125: val_loss improved from 0.01758 to 0.01755, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0179 - val_loss: 0.0175
# Epoch 127/1000
# Epoch 00126: val_loss improved from 0.01755 to 0.01752, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0179 - val_loss: 0.0175
# Epoch 128/1000
# Epoch 00127: val_loss improved from 0.01752 to 0.01747, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0178 - val_loss: 0.0175
# Epoch 129/1000
# Epoch 00128: val_loss improved from 0.01747 to 0.01745, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0178 - val_loss: 0.0175
# Epoch 130/1000
# Epoch 00129: val_loss did not improve
# 0s - loss: 0.0177 - val_loss: 0.0187
# Epoch 131/1000
# Epoch 00130: val_loss improved from 0.01745 to 0.01743, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0185 - val_loss: 0.0174
# Epoch 132/1000
# Epoch 00131: val_loss improved from 0.01743 to 0.01742, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0177 - val_loss: 0.0174
# Epoch 133/1000
# Epoch 00132: val_loss did not improve
# 0s - loss: 0.0177 - val_loss: 0.0174
# Epoch 134/1000
# Epoch 00133: val_loss improved from 0.01742 to 0.01738, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0176 - val_loss: 0.0174
# Epoch 135/1000
# Epoch 00134: val_loss improved from 0.01738 to 0.01732, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0176 - val_loss: 0.0173
# Epoch 136/1000
# Epoch 00135: val_loss improved from 0.01732 to 0.01721, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0175 - val_loss: 0.0172
# Epoch 137/1000
# Epoch 00136: val_loss improved from 0.01721 to 0.01710, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0173 - val_loss: 0.0171
# Epoch 138/1000
# Epoch 00137: val_loss improved from 0.01710 to 0.01689, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0174 - val_loss: 0.0169
# Epoch 139/1000
# Epoch 00138: val_loss improved from 0.01689 to 0.01578, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0162 - val_loss: 0.0158
# Epoch 140/1000
# Epoch 00139: val_loss improved from 0.01578 to 0.01524, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0153 - val_loss: 0.0152
# Epoch 141/1000
# Epoch 00140: val_loss improved from 0.01524 to 0.01389, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0142 - val_loss: 0.0139
# Epoch 142/1000
# Epoch 00141: val_loss improved from 0.01389 to 0.01382, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0131 - val_loss: 0.0138
# Epoch 143/1000
# Epoch 00142: val_loss improved from 0.01382 to 0.01272, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0131 - val_loss: 0.0127
# Epoch 144/1000
# Epoch 00143: val_loss improved from 0.01272 to 0.01266, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0122 - val_loss: 0.0127
# Epoch 145/1000
# Epoch 00144: val_loss improved from 0.01266 to 0.01189, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0120 - val_loss: 0.0119
# Epoch 146/1000
# Epoch 00145: val_loss improved from 0.01189 to 0.01031, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0124 - val_loss: 0.0103
# Epoch 147/1000
# Epoch 00146: val_loss did not improve
# 0s - loss: 0.0102 - val_loss: 0.0106
# Epoch 148/1000
# Epoch 00147: val_loss improved from 0.01031 to 0.00965, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0091 - val_loss: 0.0096
# Epoch 149/1000
# Epoch 00148: val_loss improved from 0.00965 to 0.00888, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0086 - val_loss: 0.0089
# Epoch 150/1000
# Epoch 00149: val_loss improved from 0.00888 to 0.00864, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0082 - val_loss: 0.0086
# Epoch 151/1000
# Epoch 00150: val_loss improved from 0.00864 to 0.00847, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0079 - val_loss: 0.0085
# Epoch 152/1000
# Epoch 00151: val_loss improved from 0.00847 to 0.00820, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0075 - val_loss: 0.0082
# Epoch 153/1000
# Epoch 00152: val_loss improved from 0.00820 to 0.00794, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0073 - val_loss: 0.0079
# Epoch 154/1000
# Epoch 00153: val_loss improved from 0.00794 to 0.00777, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0071 - val_loss: 0.0078
# Epoch 155/1000
# Epoch 00154: val_loss improved from 0.00777 to 0.00752, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0069 - val_loss: 0.0075
# Epoch 156/1000
# Epoch 00155: val_loss improved from 0.00752 to 0.00741, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0067 - val_loss: 0.0074
# Epoch 157/1000
# Epoch 00156: val_loss improved from 0.00741 to 0.00734, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0065 - val_loss: 0.0073
# Epoch 158/1000
# Epoch 00157: val_loss improved from 0.00734 to 0.00725, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0064 - val_loss: 0.0073
# Epoch 159/1000
# Epoch 00158: val_loss improved from 0.00725 to 0.00702, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0063 - val_loss: 0.0070
# Epoch 160/1000
# Epoch 00159: val_loss improved from 0.00702 to 0.00671, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0061 - val_loss: 0.0067
# Epoch 161/1000
# Epoch 00160: val_loss improved from 0.00671 to 0.00655, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0060 - val_loss: 0.0065
# Epoch 162/1000
# Epoch 00161: val_loss did not improve
# 0s - loss: 0.0059 - val_loss: 0.0066
# Epoch 163/1000
# Epoch 00162: val_loss improved from 0.00655 to 0.00637, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0058 - val_loss: 0.0064
# Epoch 164/1000
# Epoch 00163: val_loss improved from 0.00637 to 0.00609, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0057 - val_loss: 0.0061
# Epoch 165/1000
# Epoch 00164: val_loss did not improve
# 0s - loss: 0.0055 - val_loss: 0.0061
# Epoch 166/1000
# Epoch 00165: val_loss improved from 0.00609 to 0.00594, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0056 - val_loss: 0.0059
# Epoch 167/1000
# Epoch 00166: val_loss did not improve
# 0s - loss: 0.0056 - val_loss: 0.0062
# Epoch 168/1000
# Epoch 00167: val_loss improved from 0.00594 to 0.00575, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0054 - val_loss: 0.0058
# Epoch 169/1000
# Epoch 00168: val_loss improved from 0.00575 to 0.00568, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0052 - val_loss: 0.0057
# Epoch 170/1000
# Epoch 00169: val_loss improved from 0.00568 to 0.00555, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0051 - val_loss: 0.0056
# Epoch 171/1000
# Epoch 00170: val_loss did not improve
# 0s - loss: 0.0051 - val_loss: 0.0056
# Epoch 172/1000
# Epoch 00171: val_loss did not improve
# 0s - loss: 0.0053 - val_loss: 0.0057
# Epoch 173/1000
# Epoch 00172: val_loss improved from 0.00555 to 0.00554, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0051 - val_loss: 0.0055
# Epoch 174/1000
# Epoch 00173: val_loss improved from 0.00554 to 0.00534, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0049 - val_loss: 0.0053
# Epoch 175/1000
# Epoch 00174: val_loss improved from 0.00534 to 0.00528, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0048 - val_loss: 0.0053
# Epoch 176/1000
# Epoch 00175: val_loss did not improve
# 0s - loss: 0.0048 - val_loss: 0.0053
# Epoch 177/1000
# Epoch 00176: val_loss improved from 0.00528 to 0.00521, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0050 - val_loss: 0.0052
# Epoch 178/1000
# Epoch 00177: val_loss did not improve
# 0s - loss: 0.0050 - val_loss: 0.0057
# Epoch 179/1000
# Epoch 00178: val_loss improved from 0.00521 to 0.00513, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0048 - val_loss: 0.0051
# Epoch 180/1000
# Epoch 00179: val_loss improved from 0.00513 to 0.00502, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0046 - val_loss: 0.0050
# Epoch 181/1000
# Epoch 00180: val_loss improved from 0.00502 to 0.00501, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0046 - val_loss: 0.0050
# Epoch 182/1000
# Epoch 00181: val_loss did not improve
# 0s - loss: 0.0046 - val_loss: 0.0051
# Epoch 183/1000
# Epoch 00182: val_loss did not improve
# 0s - loss: 0.0048 - val_loss: 0.0052
# Epoch 184/1000
# Epoch 00183: val_loss did not improve
# 0s - loss: 0.0049 - val_loss: 0.0056
# Epoch 185/1000
# Epoch 00184: val_loss improved from 0.00501 to 0.00491, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0047 - val_loss: 0.0049
# Epoch 186/1000
# Epoch 00185: val_loss improved from 0.00491 to 0.00480, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0045 - val_loss: 0.0048
# Epoch 187/1000
# Epoch 00186: val_loss did not improve
# 0s - loss: 0.0045 - val_loss: 0.0050
# Epoch 188/1000
# Epoch 00187: val_loss did not improve
# 0s - loss: 0.0045 - val_loss: 0.0050
# Epoch 189/1000
# Epoch 00188: val_loss did not improve
# 0s - loss: 0.0049 - val_loss: 0.0050
# Epoch 190/1000
# Epoch 00189: val_loss did not improve
# 0s - loss: 0.0047 - val_loss: 0.0053
# Epoch 191/1000
# Epoch 00190: val_loss improved from 0.00480 to 0.00468, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0045 - val_loss: 0.0047
# Epoch 192/1000
# Epoch 00191: val_loss did not improve
# 0s - loss: 0.0043 - val_loss: 0.0047
# Epoch 193/1000
# Epoch 00192: val_loss did not improve
# 0s - loss: 0.0043 - val_loss: 0.0049
# Epoch 194/1000
# Epoch 00193: val_loss did not improve
# 0s - loss: 0.0044 - val_loss: 0.0048
# Epoch 195/1000
# Epoch 00194: val_loss did not improve
# 0s - loss: 0.0045 - val_loss: 0.0049
# Epoch 196/1000
# Epoch 00195: val_loss improved from 0.00468 to 0.00458, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0043 - val_loss: 0.0046
# Epoch 197/1000
# Epoch 00196: val_loss improved from 0.00458 to 0.00452, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0042 - val_loss: 0.0045
# Epoch 198/1000
# Epoch 00197: val_loss did not improve
# 0s - loss: 0.0041 - val_loss: 0.0046
# Epoch 199/1000
# Epoch 00198: val_loss did not improve
# 0s - loss: 0.0042 - val_loss: 0.0045
# Epoch 200/1000
# Epoch 00199: val_loss improved from 0.00452 to 0.00452, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0043 - val_loss: 0.0045
# Epoch 201/1000
# Epoch 00200: val_loss did not improve
# 0s - loss: 0.0042 - val_loss: 0.0045
# Epoch 202/1000
# Epoch 00201: val_loss improved from 0.00452 to 0.00443, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0041 - val_loss: 0.0044
# Epoch 203/1000
# Epoch 00202: val_loss improved from 0.00443 to 0.00439, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0040 - val_loss: 0.0044
# Epoch 204/1000
# Epoch 00203: val_loss did not improve
# 0s - loss: 0.0040 - val_loss: 0.0044
# Epoch 205/1000
# Epoch 00204: val_loss improved from 0.00439 to 0.00438, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0040 - val_loss: 0.0044
# Epoch 206/1000
# Epoch 00205: val_loss improved from 0.00438 to 0.00436, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0041 - val_loss: 0.0044
# Epoch 207/1000
# Epoch 00206: val_loss did not improve
# 0s - loss: 0.0041 - val_loss: 0.0044
# Epoch 208/1000
# Epoch 00207: val_loss improved from 0.00436 to 0.00433, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0040 - val_loss: 0.0043
# Epoch 209/1000
# Epoch 00208: val_loss improved from 0.00433 to 0.00428, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0043
# Epoch 210/1000
# Epoch 00209: val_loss did not improve
# 0s - loss: 0.0039 - val_loss: 0.0043
# Epoch 211/1000
# Epoch 00210: val_loss did not improve
# 0s - loss: 0.0039 - val_loss: 0.0043
# Epoch 212/1000
# Epoch 00211: val_loss improved from 0.00428 to 0.00426, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0040 - val_loss: 0.0043
# Epoch 213/1000
# Epoch 00212: val_loss improved from 0.00426 to 0.00425, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0040 - val_loss: 0.0042
# Epoch 214/1000
# Epoch 00213: val_loss did not improve
# 0s - loss: 0.0040 - val_loss: 0.0043
# Epoch 215/1000
# Epoch 00214: val_loss improved from 0.00425 to 0.00422, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0042
# Epoch 216/1000
# Epoch 00215: val_loss improved from 0.00422 to 0.00419, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0038 - val_loss: 0.0042
# Epoch 217/1000
# Epoch 00216: val_loss did not improve
# 0s - loss: 0.0038 - val_loss: 0.0042
# Epoch 218/1000
# Epoch 00217: val_loss did not improve
# 0s - loss: 0.0038 - val_loss: 0.0042
# Epoch 219/1000
# Epoch 00218: val_loss improved from 0.00419 to 0.00417, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0042
# Epoch 220/1000
# Epoch 00219: val_loss improved from 0.00417 to 0.00416, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0042
# Epoch 221/1000
# Epoch 00220: val_loss did not improve
# 0s - loss: 0.0039 - val_loss: 0.0042
# Epoch 222/1000
# Epoch 00221: val_loss improved from 0.00416 to 0.00416, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0042
# Epoch 223/1000
# Epoch 00222: val_loss improved from 0.00416 to 0.00411, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0038 - val_loss: 0.0041
# Epoch 224/1000
# Epoch 00223: val_loss improved from 0.00411 to 0.00410, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0038 - val_loss: 0.0041
# Epoch 225/1000
# Epoch 00224: val_loss did not improve
# 0s - loss: 0.0037 - val_loss: 0.0041
# Epoch 226/1000
# Epoch 00225: val_loss did not improve
# 0s - loss: 0.0037 - val_loss: 0.0041
# Epoch 227/1000
# Epoch 00226: val_loss improved from 0.00410 to 0.00409, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0038 - val_loss: 0.0041
# Epoch 228/1000
# Epoch 00227: val_loss improved from 0.00409 to 0.00409, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0041
# Epoch 229/1000
# Epoch 00228: val_loss improved from 0.00409 to 0.00408, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0039 - val_loss: 0.0041
# Epoch 230/1000
# Epoch 00229: val_loss improved from 0.00408 to 0.00408, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0038 - val_loss: 0.0041
# Epoch 231/1000
# Epoch 00230: val_loss improved from 0.00408 to 0.00405, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 232/1000
# Epoch 00231: val_loss improved from 0.00405 to 0.00404, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 233/1000
# Epoch 00232: val_loss did not improve
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 234/1000
# Epoch 00233: val_loss did not improve
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 235/1000
# Epoch 00234: val_loss improved from 0.00404 to 0.00403, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 236/1000
# Epoch 00235: val_loss did not improve
# 0s - loss: 0.0038 - val_loss: 0.0040
# Epoch 237/1000
# Epoch 00236: val_loss improved from 0.00403 to 0.00403, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0038 - val_loss: 0.0040
# Epoch 238/1000
# Epoch 00237: val_loss improved from 0.00403 to 0.00401, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 239/1000
# Epoch 00238: val_loss improved from 0.00401 to 0.00399, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 240/1000
# Epoch 00239: val_loss improved from 0.00399 to 0.00397, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0040
# Epoch 241/1000
# Epoch 00240: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0040
# Epoch 242/1000
# Epoch 00241: val_loss improved from 0.00397 to 0.00396, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0040
# Epoch 243/1000
# Epoch 00242: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0040
# Epoch 244/1000
# Epoch 00243: val_loss did not improve
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 245/1000
# Epoch 00244: val_loss improved from 0.00396 to 0.00395, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0040
# Epoch 246/1000
# Epoch 00245: val_loss improved from 0.00395 to 0.00395, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0039
# Epoch 247/1000
# Epoch 00246: val_loss improved from 0.00395 to 0.00395, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0039
# Epoch 248/1000
# Epoch 00247: val_loss improved from 0.00395 to 0.00393, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 249/1000
# Epoch 00248: val_loss improved from 0.00393 to 0.00393, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 250/1000
# Epoch 00249: val_loss improved from 0.00393 to 0.00393, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 251/1000
# Epoch 00250: val_loss improved from 0.00393 to 0.00389, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 252/1000
# Epoch 00251: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 253/1000
# Epoch 00252: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 254/1000
# Epoch 00253: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 255/1000
# Epoch 00254: val_loss improved from 0.00389 to 0.00387, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0037 - val_loss: 0.0039
# Epoch 256/1000
# Epoch 00255: val_loss did not improve
# 0s - loss: 0.0037 - val_loss: 0.0039
# Epoch 257/1000
# Epoch 00256: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 258/1000
# Epoch 00257: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 259/1000
# Epoch 00258: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 260/1000
# Epoch 00259: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 261/1000
# Epoch 00260: val_loss improved from 0.00387 to 0.00386, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 262/1000
# Epoch 00261: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 263/1000
# Epoch 00262: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 264/1000
# Epoch 00263: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0040
# Epoch 265/1000
# Epoch 00264: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 266/1000
# Epoch 00265: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 267/1000
# Epoch 00266: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 268/1000
# Epoch 00267: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 269/1000
# Epoch 00268: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 270/1000
# Epoch 00269: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 271/1000
# Epoch 00270: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 272/1000
# Epoch 00271: val_loss improved from 0.00386 to 0.00385, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 273/1000
# Epoch 00272: val_loss improved from 0.00385 to 0.00384, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 274/1000
# Epoch 00273: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 275/1000
# Epoch 00274: val_loss improved from 0.00384 to 0.00383, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 276/1000
# Epoch 00275: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0040
# Epoch 277/1000
# Epoch 00276: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 278/1000
# Epoch 00277: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0039
# Epoch 279/1000
# Epoch 00278: val_loss improved from 0.00383 to 0.00381, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0036 - val_loss: 0.0038
# Epoch 280/1000
# Epoch 00279: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 281/1000
# Epoch 00280: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 282/1000
# Epoch 00281: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 283/1000
# Epoch 00282: val_loss improved from 0.00381 to 0.00381, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 284/1000
# Epoch 00283: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 285/1000
# Epoch 00284: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 286/1000
# Epoch 00285: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 287/1000
# Epoch 00286: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 288/1000
# Epoch 00287: val_loss did not improve
# 0s - loss: 0.0036 - val_loss: 0.0038
# Epoch 289/1000
# Epoch 00288: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0039
# Epoch 290/1000
# Epoch 00289: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 291/1000
# Epoch 00290: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 292/1000
# Epoch 00291: val_loss improved from 0.00381 to 0.00379, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 293/1000
# Epoch 00292: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 294/1000
# Epoch 00293: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 295/1000
# Epoch 00294: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0039
# Epoch 296/1000
# Epoch 00295: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 297/1000
# Epoch 00296: val_loss did not improve
# 0s - loss: 0.0035 - val_loss: 0.0038
# Epoch 298/1000
# Epoch 00297: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 299/1000
# Epoch 00298: val_loss improved from 0.00379 to 0.00378, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 300/1000
# Epoch 00299: val_loss improved from 0.00378 to 0.00377, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 301/1000
# Epoch 00300: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0038
# Epoch 302/1000
# Epoch 00301: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0038
# Epoch 303/1000
# Epoch 00302: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0038
# Epoch 304/1000
# Epoch 00303: val_loss improved from 0.00377 to 0.00376, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 305/1000
# Epoch 00304: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 306/1000
# Epoch 00305: val_loss improved from 0.00376 to 0.00371, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0033 - val_loss: 0.0037
# Epoch 307/1000
# Epoch 00306: val_loss improved from 0.00371 to 0.00367, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0033 - val_loss: 0.0037
# Epoch 308/1000
# Epoch 00307: val_loss did not improve
# 0s - loss: 0.0034 - val_loss: 0.0038
# Epoch 309/1000
# Epoch 00308: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0038
# Epoch 310/1000
# Epoch 00309: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0037
# Epoch 311/1000
# Epoch 00310: val_loss improved from 0.00367 to 0.00361, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0033 - val_loss: 0.0036
# Epoch 312/1000
# Epoch 00311: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0037
# Epoch 313/1000
# Epoch 00312: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0037
# Epoch 314/1000
# Epoch 00313: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0036
# Epoch 315/1000
# Epoch 00314: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0036
# Epoch 316/1000
# Epoch 00315: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0038
# Epoch 317/1000
# Epoch 00316: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0037
# Epoch 318/1000
# Epoch 00317: val_loss improved from 0.00361 to 0.00354, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0032 - val_loss: 0.0035
# Epoch 319/1000
# Epoch 00318: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0037
# Epoch 320/1000
# Epoch 00319: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0037
# Epoch 321/1000
# Epoch 00320: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0035
# Epoch 322/1000
# Epoch 00321: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0036
# Epoch 323/1000
# Epoch 00322: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0037
# Epoch 324/1000
# Epoch 00323: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0036
# Epoch 325/1000
# Epoch 00324: val_loss improved from 0.00354 to 0.00343, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0032 - val_loss: 0.0034
# Epoch 326/1000
# Epoch 00325: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0035
# Epoch 327/1000
# Epoch 00326: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0036
# Epoch 328/1000
# Epoch 00327: val_loss did not improve
# 0s - loss: 0.0031 - val_loss: 0.0034
# Epoch 329/1000
# Epoch 00328: val_loss did not improve
# 0s - loss: 0.0031 - val_loss: 0.0034
# Epoch 330/1000
# Epoch 00329: val_loss did not improve
# 0s - loss: 0.0031 - val_loss: 0.0035
# Epoch 331/1000
# Epoch 00330: val_loss improved from 0.00343 to 0.00338, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0031 - val_loss: 0.0034
# Epoch 332/1000
# Epoch 00331: val_loss improved from 0.00338 to 0.00335, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0031 - val_loss: 0.0034
# Epoch 333/1000
# Epoch 00332: val_loss did not improve
# 0s - loss: 0.0030 - val_loss: 0.0034
# Epoch 334/1000
# Epoch 00333: val_loss did not improve
# 0s - loss: 0.0031 - val_loss: 0.0034
# Epoch 335/1000
# Epoch 00334: val_loss did not improve
# 0s - loss: 0.0032 - val_loss: 0.0034
# Epoch 336/1000
# Epoch 00335: val_loss did not improve
# 0s - loss: 0.0030 - val_loss: 0.0034
# Epoch 337/1000
# Epoch 00336: val_loss improved from 0.00335 to 0.00331, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0029 - val_loss: 0.0033
# Epoch 338/1000
# Epoch 00337: val_loss did not improve
# 0s - loss: 0.0030 - val_loss: 0.0034
# Epoch 339/1000
# Epoch 00338: val_loss did not improve
# 0s - loss: 0.0033 - val_loss: 0.0035
# Epoch 340/1000
# Epoch 00339: val_loss did not improve
# 0s - loss: 0.0030 - val_loss: 0.0033
# Epoch 341/1000
# Epoch 00340: val_loss improved from 0.00331 to 0.00325, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0029 - val_loss: 0.0032
# Epoch 342/1000
# Epoch 00341: val_loss did not improve
# 0s - loss: 0.0030 - val_loss: 0.0033
# Epoch 343/1000
# Epoch 00342: val_loss improved from 0.00325 to 0.00321, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0029 - val_loss: 0.0032
# Epoch 344/1000
# Epoch 00343: val_loss improved from 0.00321 to 0.00312, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0029 - val_loss: 0.0031
# Epoch 345/1000
# Epoch 00344: val_loss did not improve
# 0s - loss: 0.0029 - val_loss: 0.0032
# ...
# Epoch 830/1000
# Epoch 00829: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 831/1000
# Epoch 00830: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 832/1000
# Epoch 00831: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0021
# Epoch 833/1000
# Epoch 00832: val_loss did not improve
# 0s - loss: 0.0014 - val_loss: 0.0018
# Epoch 834/1000
# Epoch 00833: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0019
# Epoch 835/1000
# Epoch 00834: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0018
# Epoch 836/1000
# Epoch 00835: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0019
# Epoch 837/1000
# Epoch 00836: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 838/1000
# Epoch 00837: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 839/1000
# Epoch 00838: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 840/1000
# Epoch 00839: val_loss improved from 0.00168 to 0.00167, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 841/1000
# Epoch 00840: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0020
# Epoch 842/1000
# Epoch 00841: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 843/1000
# Epoch 00842: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 844/1000
# Epoch 00843: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 845/1000
# Epoch 00844: val_loss did not improve
# 0s - loss: 0.0014 - val_loss: 0.0017
# Epoch 846/1000
# Epoch 00845: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0021
# Epoch 847/1000
# Epoch 00846: val_loss did not improve
# 0s - loss: 0.0014 - val_loss: 0.0018
# Epoch 848/1000
# Epoch 00847: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 849/1000
# Epoch 00848: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 850/1000
# Epoch 00849: val_loss improved from 0.00167 to 0.00164, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0012 - val_loss: 0.0016
# Epoch 851/1000
# Epoch 00850: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 852/1000
# Epoch 00851: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 853/1000
# Epoch 00852: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 854/1000
# Epoch 00853: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 855/1000
# Epoch 00854: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 856/1000
# Epoch 00855: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 857/1000
# Epoch 00856: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 858/1000
# Epoch 00857: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0021
# Epoch 859/1000
# Epoch 00858: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0018
# Epoch 860/1000
# Epoch 00859: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0017
# Epoch 861/1000
# Epoch 00860: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0017
# Epoch 862/1000
# Epoch 00861: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 863/1000
# Epoch 00862: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 864/1000
# Epoch 00863: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 865/1000
# Epoch 00864: val_loss improved from 0.00164 to 0.00163, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 866/1000
# Epoch 00865: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 867/1000
# Epoch 00866: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 868/1000
# Epoch 00867: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 869/1000
# Epoch 00868: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 870/1000
# Epoch 00869: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 871/1000
# Epoch 00870: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 872/1000
# Epoch 00871: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 873/1000
# Epoch 00872: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 874/1000
# Epoch 00873: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 875/1000
# Epoch 00874: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 876/1000
# Epoch 00875: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 877/1000
# Epoch 00876: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 878/1000
# Epoch 00877: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0017
# Epoch 879/1000
# Epoch 00878: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0023
# Epoch 880/1000
# Epoch 00879: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0017
# Epoch 881/1000
# Epoch 00880: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 882/1000
# Epoch 00881: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 883/1000
# Epoch 00882: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 884/1000
# Epoch 00883: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 885/1000
# Epoch 00884: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 886/1000
# Epoch 00885: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 887/1000
# Epoch 00886: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 888/1000
# Epoch 00887: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 889/1000
# Epoch 00888: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 890/1000
# Epoch 00889: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 891/1000
# Epoch 00890: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 892/1000
# Epoch 00891: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 893/1000
# Epoch 00892: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0019
# Epoch 894/1000
# Epoch 00893: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 895/1000
# Epoch 00894: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 896/1000
# Epoch 00895: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 897/1000
# Epoch 00896: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 898/1000
# Epoch 00897: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 899/1000
# Epoch 00898: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 900/1000
# Epoch 00899: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 901/1000
# Epoch 00900: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 902/1000
# Epoch 00901: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0019
# Epoch 903/1000
# Epoch 00902: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 904/1000
# Epoch 00903: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 905/1000
# Epoch 00904: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 906/1000
# Epoch 00905: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 907/1000
# Epoch 00906: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 908/1000
# Epoch 00907: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 909/1000
# Epoch 00908: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 910/1000
# Epoch 00909: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 911/1000
# Epoch 00910: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 912/1000
# Epoch 00911: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 913/1000
# Epoch 00912: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 914/1000
# Epoch 00913: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 915/1000
# Epoch 00914: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 916/1000
# Epoch 00915: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 917/1000
# Epoch 00916: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 918/1000
# Epoch 00917: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 919/1000
# Epoch 00918: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0019
# Epoch 920/1000
# Epoch 00919: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 921/1000
# Epoch 00920: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 922/1000
# Epoch 00921: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 923/1000
# Epoch 00922: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 924/1000
# Epoch 00923: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 925/1000
# Epoch 00924: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 926/1000
# Epoch 00925: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 927/1000
# Epoch 00926: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 928/1000
# Epoch 00927: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 929/1000
# Epoch 00928: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 930/1000
# Epoch 00929: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 931/1000
# Epoch 00930: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 932/1000
# Epoch 00931: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0019
# Epoch 933/1000
# Epoch 00932: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 934/1000
# Epoch 00933: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 935/1000
# Epoch 00934: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 936/1000
# Epoch 00935: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 937/1000
# Epoch 00936: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0019
# Epoch 938/1000
# Epoch 00937: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 939/1000
# Epoch 00938: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 940/1000
# Epoch 00939: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 941/1000
# Epoch 00940: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 942/1000
# Epoch 00941: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 943/1000
# Epoch 00942: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 944/1000
# Epoch 00943: val_loss improved from 0.00163 to 0.00163, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 945/1000
# Epoch 00944: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0016
# Epoch 946/1000
# Epoch 00945: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0017
# Epoch 947/1000
# Epoch 00946: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 948/1000
# Epoch 00947: val_loss improved from 0.00163 to 0.00161, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 949/1000
# Epoch 00948: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 950/1000
# Epoch 00949: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 951/1000
# Epoch 00950: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 952/1000
# Epoch 00951: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 953/1000
# Epoch 00952: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 954/1000
# Epoch 00953: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 955/1000
# Epoch 00954: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 956/1000
# Epoch 00955: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 957/1000
# Epoch 00956: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 958/1000
# Epoch 00957: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0018
# Epoch 959/1000
# Epoch 00958: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 960/1000
# Epoch 00959: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 961/1000
# Epoch 00960: val_loss did not improve
# 0s - loss: 0.0014 - val_loss: 0.0017
# Epoch 962/1000
# Epoch 00961: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 963/1000
# Epoch 00962: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0017
# Epoch 964/1000
# Epoch 00963: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0022
# Epoch 965/1000
# Epoch 00964: val_loss did not improve
# 0s - loss: 0.0014 - val_loss: 0.0017
# Epoch 966/1000
# Epoch 00965: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0020
# Epoch 967/1000
# Epoch 00966: val_loss did not improve
# 0s - loss: 0.0013 - val_loss: 0.0018
# Epoch 968/1000
# Epoch 00967: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0019
# Epoch 969/1000
# Epoch 00968: val_loss did not improve
# 0s - loss: 0.0012 - val_loss: 0.0017
# Epoch 970/1000
# Epoch 00969: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 971/1000
# Epoch 00970: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 972/1000
# Epoch 00971: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 973/1000
# Epoch 00972: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 974/1000
# Epoch 00973: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 975/1000
# Epoch 00974: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 976/1000
# Epoch 00975: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 977/1000
# Epoch 00976: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 978/1000
# Epoch 00977: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 979/1000
# Epoch 00978: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 980/1000
# Epoch 00979: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 981/1000
# Epoch 00980: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 982/1000
# Epoch 00981: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 983/1000
# Epoch 00982: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 984/1000
# Epoch 00983: val_loss improved from 0.00161 to 0.00160, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 985/1000
# Epoch 00984: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 986/1000
# Epoch 00985: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 987/1000
# Epoch 00986: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0018
# Epoch 988/1000
# Epoch 00987: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 989/1000
# Epoch 00988: val_loss improved from 0.00160 to 0.00159, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0010 - val_loss: 0.0016
# Epoch 990/1000
# Epoch 00989: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0017
# Epoch 991/1000
# Epoch 00990: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0016
# Epoch 992/1000
# Epoch 00991: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0017
# Epoch 993/1000
# Epoch 00992: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 994/1000
# Epoch 00993: val_loss improved from 0.00159 to 0.00159, saving model to saved_models/weights.best.load_60.hdf5
# 0s - loss: 0.0010 - val_loss: 0.0016
# Epoch 995/1000
# Epoch 00994: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0017
# Epoch 996/1000
# Epoch 00995: val_loss did not improve
# 0s - loss: 0.0010 - val_loss: 0.0016
# Epoch 997/1000
# Epoch 00996: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0018
# Epoch 998/1000
# Epoch 00997: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017
# Epoch 999/1000
# Epoch 00998: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0016
# Epoch 1000/1000
# Epoch 00999: val_loss did not improve
# 0s - loss: 0.0011 - val_loss: 0.0017

# %% [markdown]
# ### Testing Model

# %%
# reload parameters
modelLoad.load_weights('saved_models/weights.best.load_'+str(resol)+'.hdf5')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_pred = modelLoad.predict(x_test)
print(y_pred.shape)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print("Mean Square Error: %f" % mse)
print("Mean Absolute Error: %f" % mae)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-626e855e7c32> in <module>()
#       1 from sklearn.metrics import mean_squared_error, mean_absolute_error
#       2
# ----> 3 y_pred = modelLoad.predict(x_test)
#       4 print(y_pred.shape)
#       5 mse = mean_squared_error(y_test, y_pred)
#
# NameError: name 'modelLoad' is not defined

# %%
day = 178
plt.plot(y_pred[day,:], label='Predicted')
plt.plot(y_test[day,:], label='Real')
plt.plot(x_test[day,:,1], label='Temperature')
plt.legend()
plt.show()
